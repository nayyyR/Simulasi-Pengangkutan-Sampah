# %% [markdown]
# # Simulasi Pengangkutan Sampah Desa
# ## Tugas Besar – Dasar Kecerdasan Artificial
#
# **Algoritma Heuristik yang digunakan:**
# - **Gerobak**: *Nearest Neighbor Heuristic* — selalu menuju rumah terdekat yang belum diambil
# - **Truk**: *Greedy Capacity Fill* — mengisi kapasitas dengan rumah-rumah terdekat per batch
# - **Transfer Gerobak→Truk**: *Cost-Benefit Analysis* — hitung waktu transfer vs pergi ke TPS
# - **Sharing sampah**: Satu rumah bisa diambil sebagian oleh beberapa gerobak/truk

# %%
import random
import math
from dataclasses import dataclass
from typing import List, Optional, Tuple

# CONST
# SEED = 42

NUM_HOUSES = 100
GRID_SIZE = 50 # grid 50x50 satuan
NUM_TPS = 3

CAP_GEROBAK = 15 # kg
CAP_TRUK = 200 # kg
TPS_CAP_MIN = 400
TPS_CAP_MAX = 500

HOUSE_TRASH_MIN = 0
HOUSE_TRASH_MAX = 7

# Waktu operasi (menit sejak 00:00)
GEROBAK_START = 6 * 60 # 06:00
GEROBAK_END = 15 * 60 # 15:00
TRUK_START = 8 * 60 # 08:00
TRUK_END = 17 * 60 # 17:00

# Loading time
GEROBAK_LOAD_PER_KG = 2 # 2 menit/kg
TRUK_LOAD_PER_10KG = 2 # 2 menit per 10 kg

# Travel time
GEROBAK_TRAVEL_PER_DIST = 3 # 3 menit per 1 satuan jarak
TRUK_TRAVEL_PER_5DIST = 3 # 3 menit per 5 satuan jarak

print("Const ready")
# Out:
# Const ready

# %% [markdown]
# ## Helper Func

# %%
# Konversi menit sejak 00:00 ke format HH:MM
def mins_to_hhmm(m: int) -> str:
    h = m // 60
    mn = m % 60
    return f"{h:02d}:{mn:02d}"

# Jarak Euclidean antara dua titik
def euclidean(a, b) -> float:
    return math.sqrt((a[0]-b[0])**2 + (a[1]-b[1])**2)

# Waktu tempuh gerobak: 3 menit per 1 satuan jarak
def gerobak_travel_time(dist: float) -> float:
    return dist * GEROBAK_TRAVEL_PER_DIST

# Waktu tempuh truk: 3 menit per 5 satuan jarak = 0.6 menit/satuan
def truk_travel_time(dist: float) -> float:
    return dist * (TRUK_TRAVEL_PER_5DIST / 5.0)

# Waktu loading gerobak: 2 menit per kg
def gerobak_load_time(kg: float) -> float:
    return kg * GEROBAK_LOAD_PER_KG

# Waktu loading truk: 2 menit per 10 kg
def truk_load_time(kg: float) -> float:
    return (kg / 10.0) * TRUK_LOAD_PER_10KG

print("Helper functions ready")
# Out:
# Helper functions ready

# %% [markdown]
# ## Data Classes (House, TPS, LogEntry)

# %%
@dataclass
class House:
    id: int
    x: float
    y: float
    trash_initial: float
    trash_remaining: float = 0.0
    assigned_tps: int = 0   # ID TPS yang bertanggung jawab atas rumah ini (diisi saat pre-assignment)

    def __post_init__(self):
        self.trash_remaining = self.trash_initial


@dataclass
class TPS:
    id: int
    x: float
    y: float
    capacity: float
    stored: float = 0.0

    @property
    def available(self):
        return self.capacity - self.stored


@dataclass
class LogEntry:
    actor: str
    time: str
    event: str
    detail: str

    def __str__(self):
        return f"[{self.time}] {self.actor:<12} | {self.event:<20} | {self.detail}"

print("Data classes ready")
# Out:
# Data classes ready

# %% [markdown]
# ## Agent Classes (Gerobak & Truk)

# %%
# Agen gerobak sampah
# Heuristik: Nearest Neighbor — selalu menuju rumah terdekat yang ada sampah (di zonanya)
# Bisa transfer sampah ke truk jika lebih efisien daripada ke TPS
class Gerobak:
    def __init__(self, gid: int, start_pos: Tuple[float, float]):
        self.id = gid
        self.x, self.y = start_pos
        self.load = 0.0
        self.time = GEROBAK_START
        self.total_dist = 0.0
        self.total_time_travel = 0.0
        self.total_time_load = 0.0
        self.logs: List[LogEntry] = []
        self.active = True
        self.trips_to_tps = 0
        self.trips_to_truk = 0
        self.home_tps_id: int = 0   # ID TPS zona kerja gerobak ini (diisi saat pre-assignment)

    @property
    def pos(self): return (self.x, self.y)

    def name(self): return f"Gerobak-{self.id}"

    def log(self, event: str, detail: str):
        self.logs.append(LogEntry(
            actor=self.name(),
            time=mins_to_hhmm(int(self.time)),
            event=event, detail=detail))

    def move_to(self, tx, ty):
        dist = euclidean(self.pos, (tx, ty))
        travel = gerobak_travel_time(dist)
        self.x, self.y = tx, ty
        self.total_dist += dist
        self.total_time_travel += travel
        self.time += travel
        return dist, travel

    # Ambil sampah dari rumah (bisa sebagian — sharing support)
    def collect_from_house(self, house: 'House', kg: float):
        load_t = gerobak_load_time(kg)
        house.trash_remaining = max(0.0, house.trash_remaining - kg)
        self.load += kg
        self.total_time_load += load_t
        self.time += load_t
        self.log("AMBIL_SAMPAH",
            f"Rumah-{house.id} ({house.x:.1f},{house.y:.1f}) "
            f"ambil {kg:.2f}kg | sisa rumah {house.trash_remaining:.2f}kg "
            f"| muatan gerobak {self.load:.2f}kg")

    # Buang semua muatan ke TPS
    def dump_to_tps(self, tps: 'TPS'):
        kg = self.load
        load_t = gerobak_load_time(kg)
        tps.stored = min(tps.capacity, tps.stored + kg)
        self.total_time_load += load_t
        self.time += load_t
        self.log("BUANG_TPS",
            f"TPS-{tps.id} ({tps.x:.1f},{tps.y:.1f}) "
            f"buang {kg:.2f}kg | TPS {tps.stored:.1f}/{tps.capacity:.1f}kg")
        self.load = 0.0
        self.trips_to_tps += 1

    # Titipkan sebagian/seluruh muatan ke truk saat berpapasan
    def dump_to_truck(self, truk: 'Truk', kg: float):
        load_t = gerobak_load_time(kg)
        self.load = max(0.0, self.load - kg)
        self.total_time_load += load_t
        self.time += load_t
        self.log("TITIP_TRUK",
            f"Transfer {kg:.2f}kg ke {truk.name()} | "
            f"sisa di gerobak {self.load:.2f}kg")
        self.trips_to_truk += 1

# Agen truk sampah.
# Heuristik: Greedy Capacity Fill — ambil batch rumah terdekat sampai hampir penuh.
# Mulai dari TPS dan kembali ke TPS saat penuh.
# Work Stealing: jika zona sendiri bersih, bantu zona lain.
class Truk:
    def __init__(self, tid: int, tps: 'TPS'):
        self.id = tid
        self.x, self.y = tps.x, tps.y
        self.home_tps = tps
        self.home_tps_id: int = tps.id   # ID TPS zona kerja truk ini
        self.load = 0.0
        self.time = TRUK_START
        self.total_dist = 0.0
        self.total_time_travel = 0.0
        self.total_time_load = 0.0
        self.logs: List[LogEntry] = []
        self.active = True
        self.trips_to_tps = 0
        self.received_from_gerobak_kg = 0.0

    @property
    def pos(self): return (self.x, self.y)

    def name(self): return f"Truk-{self.id}"

    def log(self, event: str, detail: str):
        self.logs.append(LogEntry(
            actor=self.name(),
            time=mins_to_hhmm(int(self.time)),
            event=event, detail=detail))

    def move_to(self, tx, ty):
        dist = euclidean(self.pos, (tx, ty))
        travel = truk_travel_time(dist)
        self.x, self.y = tx, ty
        self.total_dist += dist
        self.total_time_travel += travel
        self.time += travel
        return dist, travel

    # Ambil sampah dari rumah
    def collect_from_house(self, house: 'House', kg: float):
        load_t = truk_load_time(kg)
        house.trash_remaining = max(0.0, house.trash_remaining - kg)
        self.load += kg
        self.total_time_load += load_t
        self.time += load_t
        self.log("AMBIL_SAMPAH",
            f"Rumah-{house.id} ({house.x:.1f},{house.y:.1f}) "
            f"ambil {kg:.2f}kg | sisa rumah {house.trash_remaining:.2f}kg "
            f"| muatan truk {self.load:.2f}kg")

    # Buang semua muatan ke TPS
    def dump_to_tps(self, tps: 'TPS'):
        kg = self.load
        load_t = truk_load_time(kg)
        tps.stored = min(tps.capacity, tps.stored + kg)
        self.total_time_load += load_t
        self.time += load_t
        self.log("BUANG_TPS",
            f"TPS-{tps.id} ({tps.x:.1f},{tps.y:.1f}) "
            f"buang {kg:.2f}kg | TPS {tps.stored:.1f}/{tps.capacity:.1f}kg")
        self.load = 0.0
        self.trips_to_tps += 1

    # Terima sampah dari gerobak saat berpapasan
    def receive_from_gerobak(self, gerobak: 'Gerobak', kg: float):
        load_t = truk_load_time(kg)
        self.load += kg
        self.total_time_load += load_t
        self.time += load_t
        self.received_from_gerobak_kg += kg
        self.log("TERIMA_GEROBAK",
            f"Terima {kg:.2f}kg dari {gerobak.name()} | "
            f"muatan truk {self.load:.2f}kg")

print("Agent classes ready")
# Out:
# Agent classes ready

# %% [markdown]
# ## Func Generate Peta Desa

# %%
# Generate posisi rumah dan TPS secara acak
# Semua posisi (rumah maupun TPS) di-random di dalam grid
# Constraint: posisi TPS tidak boleh sama/bertumpuk dengan rumah
def generate_map():
    houses = []
    positions = set()

    # Generate posisi rumah secara random
    for i in range(NUM_HOUSES):
        while True:
            x = round(random.uniform(0, GRID_SIZE), 1)
            y = round(random.uniform(0, GRID_SIZE), 1)
            if (x, y) not in positions:
                positions.add((x, y))
                break
        trash = round(random.uniform(HOUSE_TRASH_MIN, HOUSE_TRASH_MAX), 2)
        houses.append(House(id=i+1, x=x, y=y, trash_initial=trash))

    # Generate posisi TPS secara random
    tps_list = []
    for i in range(NUM_TPS):
        while True:
            tx = round(random.uniform(0, GRID_SIZE), 1)
            ty = round(random.uniform(0, GRID_SIZE), 1)
            if (tx, ty) not in positions:
                positions.add((tx, ty))
                break
        cap = round(random.uniform(TPS_CAP_MIN, TPS_CAP_MAX), 1)
        tps_list.append(TPS(id=i+1, x=tx, y=ty, capacity=cap))

    return houses, tps_list

print("Func Generate Map Ready")
# Out:
# Func Generate Map Ready

# %% [markdown]
# ## Inisialisasi Data

# %%
random.seed()

# Jumlah agen
NUM_GEROBAK = random.randint(5, 7)
NUM_TRUK = random.randint(2, 4)

# Peta: rumah + TPS
houses, tps_list = generate_map()

# Truk mulai dari TPS
truk_list: List[Truk] = []
for i in range(NUM_TRUK):
    home_tps = tps_list[i % NUM_TPS]
    truk_list.append(Truk(i+1, home_tps))

# Gerobak mulai dari titik random
gerobak_list: List[Gerobak] = []
for i in range(NUM_GEROBAK):
    sx = round(random.uniform(2, GRID_SIZE - 2), 1)
    sy = round(random.uniform(2, GRID_SIZE - 2), 1)
    gerobak_list.append(Gerobak(i+1, (sx, sy)))

# Snapshot koordinat awal untuk verifikasi konsistensi
_snapshot_houses = {h.id: (h.x, h.y) for h in houses}
_snapshot_tps = {t.id: (t.x, t.y) for t in tps_list}
_snapshot_gerobak = {g.id: (g.x, g.y) for g in gerobak_list}

# Tampilkan ringkasan
total_trash = sum(h.trash_initial for h in houses)
# print(f"INISIALISASI DATA (SEED={SEED})")
print()
print(f"Jumlah gerobak: {NUM_GEROBAK}")
print(f"Jumlah truk: {NUM_TRUK}")
print(f"Jumlah TPS: {NUM_TPS}")
print(f"Jumlah rumah: {NUM_HOUSES}")
print(f"Total sampah: {total_trash:.2f} kg")
print(f"Rata-rata/rumah: {total_trash/NUM_HOUSES:.2f} kg")
print()
print("Lokasi TPS (random):")
for t in tps_list:
    print(f"TPS-{t.id}: ({t.x:.1f}, {t.y:.1f})  kap={t.capacity:.1f} kg")
print()
print("Posisi awal Gerobak (random):")
for g in gerobak_list:
    print(f"Gerobak-{g.id}: ({g.x:.1f}, {g.y:.1f})")
print()
print("Posisi awal Truk (dari TPS):")
for t in truk_list:
    print(f"Truk-{t.id}: ({t.x:.1f}, {t.y:.1f})  <- TPS-{t.home_tps.id}")
# Out:
# Jumlah gerobak: 7
# Jumlah truk: 3
# Jumlah TPS: 3
# Jumlah rumah: 100
# Total sampah: 352.56 kg
# Rata-rata/rumah: 3.53 kg
#
# Lokasi TPS (random):
# TPS-1: (7.8, 4.7)  kap=443.0 kg
# TPS-2: (44.0, 43.0)  kap=415.1 kg
# TPS-3: (49.3, 12.0)  kap=473.5 kg
#
# Posisi awal Gerobak (random):
# Gerobak-1: (29.4, 23.3)
# Gerobak-2: (18.4, 35.1)
# Gerobak-3: (43.5, 43.8)
# Gerobak-4: (39.5, 32.2)
# Gerobak-5: (11.6, 18.8)
# Gerobak-6: (24.1, 23.4)
# Gerobak-7: (26.8, 23.3)
#
# Posisi awal Truk (dari TPS):
# Truk-1: (7.8, 4.7)  <- TPS-1
# Truk-2: (44.0, 43.0)  <- TPS-2
# Truk-3: (49.3, 12.0)  <- TPS-3

# %% [markdown]
# ### Visualisasi Peta Penduduk

# %%
# Cek konsistensi koordinat
print(f"Verifikasi: {len(houses)} rumah, {len(tps_list)} TPS")
print(f"Rumah-1: ({houses[0].x:.1f}, {houses[0].y:.1f}) sampah={houses[0].trash_initial:.2f}kg")
print(f"TPS-1: ({tps_list[0].x:.1f}, {tps_list[0].y:.1f}) kap={tps_list[0].capacity:.1f}kg")
print()
assert all(_snapshot_houses[h.id] == (h.x, h.y) for h in houses), \
    "ERROR: Koordinat rumah berubah dari inisialisasi!"
assert all(_snapshot_tps[t.id] == (t.x, t.y) for t in tps_list), \
    "ERROR: Koordinat TPS berubah dari inisialisasi!"
print("Koordinat terverifikasi ...")

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

fig, ax = plt.subplots(figsize=(10, 10))
ax.set_xlim(-1, GRID_SIZE+1)
ax.set_ylim(-1, GRID_SIZE+1)
ax.set_facecolor('#f0f4f0')
fig.patch.set_facecolor('#e8f0e8')

# Plot rumah berdasarkan jumlah sampah
trash_vals = [h.trash_initial for h in houses]
hx = [h.x for h in houses]
hy = [h.y for h in houses]
sc = ax.scatter(hx, hy, c=trash_vals, cmap='YlOrRd', s=60, alpha=0.85, zorder=3, vmin=0, vmax=HOUSE_TRASH_MAX, edgecolors='gray', linewidths=0.3)
plt.colorbar(sc, ax=ax, label='Sampah (kg)', shrink=0.6)

# Plot TPS
tps_colors = ['#1a6b3c', '#155a8a', '#8b1a1a']
tps_labels = []
for i, tps in enumerate(tps_list):
    ax.scatter(tps.x, tps.y, c=tps_colors[i], s=300, marker='s', zorder=5, edgecolors='black', linewidths=1.5)
    ax.annotate(f'TPS-{tps.id}\n({tps.capacity:.0f}kg)', (tps.x, tps.y), textcoords="offset points", xytext=(8, 8), fontsize=9, fontweight='bold', color=tps_colors[i])
    tps_labels.append(mpatches.Patch(color=tps_colors[i], label=f'TPS-{tps.id} ({tps.x:.0f},{tps.y:.0f})'))

ax.set_title('Peta Desa – Distribusi Sampah & Lokasi TPS', fontsize=14, fontweight='bold', pad=15)
ax.set_xlabel('Koordinat X (satuan jarak)', fontsize=11)
ax.set_ylabel('Koordinat Y (satuan jarak)', fontsize=11)
ax.grid(True, alpha=0.3, linestyle='--')
ax.legend(handles=tps_labels, loc='upper left', fontsize=9)
plt.tight_layout()
plt.savefig('peta_desa.png', dpi=120, bbox_inches='tight')
plt.show()
print("Peta saved")
# Out:
# Verifikasi: 100 rumah, 3 TPS
# Rumah-1: (32.4, 36.4) sampah=2.45kg
# TPS-1: (7.8, 4.7) kap=443.0kg
#
# Koordinat terverifikasi ...
# Peta saved

# %% [markdown]
# ## Fungsi Heuristik

# %%
# Temukan TPS terdekat yang masih ada kapasitas
def nearest_tps(pos: Tuple, tps_list: List[TPS]) -> Optional[TPS]:
    candidates = [t for t in tps_list if t.available > 0.5]
    if not candidates:
        return None
    return min(candidates, key=lambda t: euclidean(pos, (t.x, t.y)))

# Temukan rumah terdekat yang masih ada sampah (dari daftar yang diberikan)
def nearest_house(pos: Tuple, houses: List[House]) -> Optional[House]:
    candidates = [h for h in houses if h.trash_remaining > 0.01]
    if not candidates:
        return None
    return min(candidates, key=lambda h: euclidean(pos, (h.x, h.y)))

# Heuristik cost-benefit: Bandingkan waktu transfer ke truk vs langsung ke TPS
def cost_benefit_transfer(gerobak: Gerobak, truk: Truk, tps_list: List[TPS]) -> Tuple[str, float]:
    if truk.load + gerobak.load > CAP_TRUK * 0.98:
        return ('skip', 0)
    if gerobak.load < 1.0:
        return ('skip', 0)
    dist_g_to_t = euclidean(gerobak.pos, truk.pos)
    time_A = gerobak_travel_time(dist_g_to_t) + gerobak_load_time(gerobak.load)
    best_tps = nearest_tps(gerobak.pos, tps_list)
    if best_tps is None:
        return ('skip', 0)
    dist_g_to_tps = euclidean(gerobak.pos, (best_tps.x, best_tps.y))
    time_B = gerobak_travel_time(dist_g_to_tps) + gerobak_load_time(gerobak.load)
    if dist_g_to_t < dist_g_to_tps * 0.75 and gerobak.load >= 3.0:
        return ('transfer', time_B - time_A)
    return ('skip', 0)

# Greedy: rencanakan batch pengambilan untuk truk dari daftar rumah yang diberikan
def greedy_batch_plan(truk: Truk, houses: List[House], max_houses: int = 8) -> List[Tuple[House, float]]:
    plan = []
    remaining_cap = CAP_TRUK - truk.load
    current_pos = truk.pos
    visited_ids = set()
    while remaining_cap > 0.5 and len(plan) < max_houses:
        candidates = [h for h in houses if h.id not in visited_ids and h.trash_remaining > 0.01]
        if not candidates:
            break
        best = min(candidates, key=lambda h: euclidean(current_pos, (h.x, h.y)))
        take = min(best.trash_remaining, remaining_cap)
        plan.append((best, take))
        remaining_cap -= take
        current_pos = (best.x, best.y)
        visited_ids.add(best.id)
    return plan

# ============================================================
# PRE-ASSIGNMENT FUNCTIONS (Algoritma Penjatahan)
# ============================================================

def assign_houses_to_tps(houses: List[House], tps_list: List[TPS]) -> None:
    """
    Fase 1: Setiap TPS memilih rumah-rumah terdekat hingga kuota terpenuhi.
    Kuota dibagi merata: ceil(NUM_HOUSES / NUM_TPS) per TPS.
    Rumah yang sudah dipilih tidak bisa dipilih TPS lain.
    Hasilnya: setiap House.assigned_tps diisi dengan ID TPS-nya.
    """
    import math
    quota = math.ceil(len(houses) / len(tps_list))  # 34 untuk 100 rumah / 3 TPS
    unassigned = list(houses)

    # Urutkan TPS dari yang paling sedikit rumahnya (agar pembagian adil bila sisa tidak rata)
    for tps in tps_list:
        count = 0
        while count < quota and unassigned:
            # Pilih rumah terdekat yang belum diassign
            best = min(unassigned, key=lambda h: euclidean((tps.x, tps.y), (h.x, h.y)))
            best.assigned_tps = tps.id
            unassigned.remove(best)
            count += 1

    # Jika masih ada sisa (karena pembulatan), assign ke TPS terdekat
    for h in unassigned:
        closest_tps = min(tps_list, key=lambda t: euclidean((t.x, t.y), (h.x, h.y)))
        h.assigned_tps = closest_tps.id

    # Print ringkasan
    for tps in tps_list:
        jumlah = sum(1 for h in houses if h.assigned_tps == tps.id)
        print(f"  TPS-{tps.id} ({tps.x:.1f},{tps.y:.1f}) -> {jumlah} rumah")


def recruit_gerobak_to_tps(gerobak_list: List[Gerobak], tps_list: List[TPS], houses: List[House]) -> None:
    """
    Fase 2: TPS merekrut gerobak terdekat (dari posisi spawn gerobak).
    TPS dengan lebih banyak rumah mendapat jatah gerobak lebih banyak (Round-Robin).
    Hasilnya: setiap Gerobak.home_tps_id diisi dengan ID TPS-nya.
    """
    # Hitung beban tiap TPS (jumlah rumah)
    beban = {tps.id: sum(1 for h in houses if h.assigned_tps == tps.id) for tps in tps_list}

    # Tentukan jatah gerobak per TPS (Round-Robin berdasarkan beban)
    jatah = {tps.id: 1 for tps in tps_list}   # modal awal: 1 per TPS
    sisa = len(gerobak_list) - len(tps_list)

    # Urutkan TPS dari beban terbesar untuk Round-Robin
    urutan = sorted(tps_list, key=lambda t: beban[t.id], reverse=True)
    i = 0
    while sisa > 0:
        jatah[urutan[i % len(urutan)].id] += 1
        sisa -= 1
        i += 1

    # TPS rekrut gerobak terdekat sesuai jatah, round-robin antar TPS
    unrecruited = list(gerobak_list)
    for tps in urutan:
        count = 0
        while count < jatah[tps.id] and unrecruited:
            best = min(unrecruited, key=lambda g: euclidean((tps.x, tps.y), g.pos))
            best.home_tps_id = tps.id
            unrecruited.remove(best)
            count += 1

    # Jika ada sisa gerobak (edge case), assign ke TPS dengan beban terbanyak
    for g in unrecruited:
        g.home_tps_id = urutan[0].id

    # Print ringkasan
    for tps in tps_list:
        rekrutan = [g.id for g in gerobak_list if g.home_tps_id == tps.id]
        print(f"  TPS-{tps.id} -> Gerobak {rekrutan} ({len(rekrutan)} gerobak)")


def assign_truk_to_tps(truk_list: List[Truk], tps_list: List[TPS], houses: List[House]) -> None:
    """
    Fase 3: Assign truk ke TPS — 1 truk per TPS (average case).
    - NUM_TRUK = 2: TPS terkecil tidak dapat truk awal
    - NUM_TRUK = 3: masing-masing 1 truk
    - NUM_TRUK = 4: TPS terbesar dapat 2 truk
    Hasilnya: setiap Truk.home_tps_id diisi dengan ID TPS-nya.
    """
    beban = {tps.id: sum(1 for h in houses if h.assigned_tps == tps.id) for tps in tps_list}
    urutan = sorted(tps_list, key=lambda t: beban[t.id], reverse=True)

    # Tentukan jatah truk per TPS
    jatah = {tps.id: 0 for tps in tps_list}
    for i, t in enumerate(truk_list):
        tps_terpilih = urutan[i % len(urutan)]
        jatah[tps_terpilih.id] += 1
        t.home_tps_id = tps_terpilih.id
        t.home_tps = tps_terpilih  # update referensi TPS juga

    # Print ringkasan
    for tps in tps_list:
        truck_ids = [t.id for t in truk_list if t.home_tps_id == tps.id]
        print(f"  TPS-{tps.id} -> Truk {truck_ids} ({len(truck_ids)} truk)")


def cari_rumah_gerobak(g: Gerobak, houses: List[House]) -> Optional[House]:
    """
    Gerobak hanya mencari rumah di zona TPS-nya sendiri (assigned_tps == home_tps_id).
    Tidak ada Work Stealing untuk gerobak.
    """
    zona = [h for h in houses if h.assigned_tps == g.home_tps_id and h.trash_remaining > 0.01]
    if not zona:
        return None
    return min(zona, key=lambda h: euclidean(g.pos, (h.x, h.y)))


def cari_rumah_truk(t: Truk, houses: List[House]) -> Optional[House]:
    """
    Truk prioritas zona sendiri dulu.
    Jika zona sendiri bersih -> Work Stealing: bantu zona lain yang sisa sampahnya paling banyak.
    """
    zona_sendiri = [h for h in houses if h.assigned_tps == t.home_tps_id and h.trash_remaining > 0.01]
    if zona_sendiri:
        return min(zona_sendiri, key=lambda h: euclidean(t.pos, (h.x, h.y)))

    # Work Stealing: semua zona
    semua_sisa = [h for h in houses if h.trash_remaining > 0.01]
    if not semua_sisa:
        return None
    return min(semua_sisa, key=lambda h: euclidean(t.pos, (h.x, h.y)))

# ============================================================
# PRE-ASSIGNMENT: Penjatahan Rumah, Gerobak, dan Truk ke TPS
# Dijalankan di sini karena fungsinya baru saja didefinisikan di atas
# ============================================================
print("\nMenjalankan pre-assignment...")

print("Fase 1 - Assign rumah ke TPS (Nearest N, kuota merata):")
assign_houses_to_tps(houses, tps_list)

print("Fase 2 - TPS rekrut gerobak terdekat (Round-Robin):")
recruit_gerobak_to_tps(gerobak_list, tps_list, houses)

print("Fase 3 - Assign truk ke TPS:")
assign_truk_to_tps(truk_list, tps_list, houses)

print("Pre-assignment selesai.")
# Out:
# Menjalankan pre-assignment...
# Fase 1 - Assign rumah ke TPS (Nearest N, kuota merata):
#   TPS-1 (7.8,4.7) -> 34 rumah
#   TPS-2 (44.0,43.0) -> 34 rumah
#   TPS-3 (49.3,12.0) -> 32 rumah
# Fase 2 - TPS rekrut gerobak terdekat (Round-Robin):
#   TPS-1 -> Gerobak [5, 6, 7] (3 gerobak)
#   TPS-2 -> Gerobak [3, 4] (2 gerobak)
#   TPS-3 -> Gerobak [1, 2] (2 gerobak)
# Fase 3 - Assign truk ke TPS:
#   TPS-1 -> Truk [1] (1 truk)
#   TPS-2 -> Truk [2] (1 truk)
#   TPS-3 -> Truk [3] (1 truk)
# Pre-assignment selesai.

# %% [markdown]
# ## Jalankan Simulasi

# %%
# ============================================================
# SIMULASI UTAMA — Concurrent Event-Driven + Sistem Penjatahan
# ============================================================
# Gerobak dan truk berjalan dalam SATU loop bersama (concurrent).
# Gerobak hanya melayani rumah di zona TPS-nya (home_tps_id).
# Truk prioritas zona sendiri, lalu Work Stealing jika zonanya bersih.
# ============================================================
print("Menjalankan simulasi concurrent dengan sistem penjatahan...")

# Reset state semua rumah dan TPS sebelum simulasi
for h in houses:
    h.trash_remaining = h.trash_initial
for tps in tps_list:
    tps.stored = 0.0

# Reset state semua agen
for g in gerobak_list:
    gx, gy = _snapshot_gerobak[g.id]
    g.x, g.y = gx, gy
    g.load = 0.0
    g.time = GEROBAK_START
    g.total_dist = 0.0
    g.total_time_travel = 0.0
    g.total_time_load = 0.0
    g.logs = []
    g.trips_to_tps = 0
    g.trips_to_truk = 0
    g.log("MULAI", f"Posisi awal ({g.x:.1f},{g.y:.1f}) | zona TPS-{g.home_tps_id}")

for t in truk_list:
    t.x, t.y = t.home_tps.x, t.home_tps.y
    t.load = 0.0
    t.time = TRUK_START
    t.total_dist = 0.0
    t.total_time_travel = 0.0
    t.total_time_load = 0.0
    t.logs = []
    t.trips_to_tps = 0
    t.received_from_gerobak_kg = 0.0
    t.log("MULAI", f"Mulai dari TPS-{t.home_tps.id} ({t.x:.1f},{t.y:.1f})")

# Status selesai untuk tiap agen
gerobak_done = [False] * NUM_GEROBAK
truk_done    = [False] * NUM_TRUK
iteration = 0

while not (all(gerobak_done) and all(truk_done)):
    iteration += 1
    if iteration > 500_000:
        print("Safety break!")
        break

    active_gerobak = [(i, g) for i, g in enumerate(gerobak_list) if not gerobak_done[i]]
    active_truk    = [(i, t) for i, t in enumerate(truk_list)    if not truk_done[i]]

    candidates = [("g", i, a) for i, a in active_gerobak] +                  [("t", i, a) for i, a in active_truk]
    if not candidates:
        break

    # Pilih agen dengan waktu (time) terkecil — event-driven scheduling
    agent_type, idx, agent = min(candidates, key=lambda x: x[2].time)

    # ──────────────────────────────────────────────
    # AKSI GEROBAK
    # Heuristik: Nearest Neighbor — hanya di zona TPS-nya (home_tps_id)
    # ──────────────────────────────────────────────
    if agent_type == "g":
        g = agent

        if g.time >= GEROBAK_END:
            gerobak_done[idx] = True
            g.log("SELESAI_WAKTU",
                  f"Operasi selesai {mins_to_hhmm(GEROBAK_END)} | "
                  f"sisa muatan {g.load:.2f}kg | jarak total {g.total_dist:.2f}")
            continue

        # Gerobak hampir penuh (>=90%) -> coba titip ke truk atau buang ke TPS
        if g.load >= CAP_GEROBAK * 0.9:
            best_truk = None
            best_dist = float('inf')
            for t in truk_list:
                if t.time >= TRUK_END:
                    continue
                d = euclidean(g.pos, t.pos)
                can_accept = CAP_TRUK - t.load
                if d < best_dist and can_accept >= 5.0 and d < 12:
                    best_dist = d
                    best_truk = t

            if best_truk:
                tps_for_compare = nearest_tps(g.pos, tps_list)
                dist_tps = euclidean(g.pos, (tps_for_compare.x, tps_for_compare.y)) if tps_for_compare else float('inf')
                if best_dist < dist_tps * 0.75:
                    g.move_to(best_truk.x, best_truk.y)
                    if g.time >= GEROBAK_END:
                        gerobak_done[idx] = True
                        g.log("SELESAI_WAKTU", "Waktu habis saat menuju truk")
                        continue
                    transfer_kg = min(g.load, CAP_TRUK - best_truk.load)
                    g.dump_to_truck(best_truk, transfer_kg)
                    best_truk.receive_from_gerobak(g, transfer_kg)
                    continue

            tps = nearest_tps(g.pos, tps_list)
            if tps is None:
                gerobak_done[idx] = True
                g.log("ERROR", "Semua TPS penuh!")
                continue
            g.move_to(tps.x, tps.y)
            if g.time >= GEROBAK_END:
                gerobak_done[idx] = True
                g.log("SELESAI_WAKTU", "Waktu habis saat menuju TPS")
                continue
            g.dump_to_tps(tps)
            continue

        # Cari rumah di zona sendiri (Nearest Neighbor, filtered by assigned_tps)
        house = cari_rumah_gerobak(g, houses)
        if house is None:
            # Zona sendiri bersih — buang sisa muatan lalu selesai (gerobak tidak Work Stealing)
            if g.load > 0.01:
                tps = nearest_tps(g.pos, tps_list)
                if tps:
                    g.move_to(tps.x, tps.y)
                    if g.time < GEROBAK_END:
                        g.dump_to_tps(tps)
            gerobak_done[idx] = True
            g.log("SELESAI_SAMPAH",
                  f"Zona TPS-{g.home_tps_id} bersih | jarak {g.total_dist:.2f} | "
                  f"waktu {g.time - GEROBAK_START:.0f} menit")
            continue

        g.move_to(house.x, house.y)
        if g.time >= GEROBAK_END:
            gerobak_done[idx] = True
            g.log("SELESAI_WAKTU", f"Waktu habis di jalan ke Rumah-{house.id}")
            continue

        space = CAP_GEROBAK - g.load
        take = min(house.trash_remaining, space)
        if take > 0.01:
            g.collect_from_house(house, take)

        if g.time >= GEROBAK_END:
            gerobak_done[idx] = True
            g.log("SELESAI_WAKTU", "Waktu habis saat loading")
            continue

        # Cek berpapasan dengan truk untuk transfer (radius < 5 satuan)
        for t in truk_list:
            if t.time >= TRUK_END:
                continue
            d = euclidean(g.pos, t.pos)
            if d < 5.0 and g.load >= 3.0:
                can_accept = CAP_TRUK - t.load
                if can_accept >= 3.0:
                    decision, saving = cost_benefit_transfer(g, t, tps_list)
                    if decision == 'transfer':
                        transfer_kg = min(g.load, can_accept)
                        g.dump_to_truck(t, transfer_kg)
                        t.receive_from_gerobak(g, transfer_kg)
                        break

    # ──────────────────────────────────────────────
    # AKSI TRUK
    # Prioritas zona sendiri, lalu Work Stealing jika zona bersih
    # ──────────────────────────────────────────────
    elif agent_type == "t":
        t = agent

        if t.time < TRUK_START:
            t.time = TRUK_START
            continue

        if t.time >= TRUK_END:
            truk_done[idx] = True
            t.log("SELESAI_WAKTU",
                  f"Operasi selesai {mins_to_hhmm(TRUK_END)} | "
                  f"sisa muatan {t.load:.2f}kg | jarak total {t.total_dist:.2f}")
            continue

        # Truk hampir penuh -> kembali ke TPS
        if t.load >= CAP_TRUK * 0.9:
            tps = nearest_tps(t.pos, tps_list)
            if tps is None:
                truk_done[idx] = True
                t.log("ERROR", "Semua TPS penuh!")
                continue
            t.move_to(tps.x, tps.y)
            if t.time >= TRUK_END:
                truk_done[idx] = True
                t.log("SELESAI_WAKTU", "Waktu habis saat menuju TPS")
                continue
            t.dump_to_tps(tps)
            continue

        # Cari rumah: zona sendiri dulu, baru Work Stealing
        # cari_rumah_truk() sudah menangani logika ini secara otomatis
        rumah_kandidat = [h for h in houses if h.assigned_tps == t.home_tps_id and h.trash_remaining > 0.01]
        if rumah_kandidat:
            # Zona sendiri masih ada sampah — gunakan batch plan di zona sendiri
            plan = greedy_batch_plan(t, rumah_kandidat, max_houses=6)
        else:
            # Work Stealing: zona sendiri bersih, ambil dari mana saja
            plan = greedy_batch_plan(t, houses, max_houses=6)

        if not plan:
            if t.load > 0.01:
                tps = nearest_tps(t.pos, tps_list)
                if tps:
                    t.move_to(tps.x, tps.y)
                    if t.time < TRUK_END:
                        t.dump_to_tps(tps)
            truk_done[idx] = True
            t.log("SELESAI_SAMPAH",
                  f"Semua sampah habis | jarak {t.total_dist:.2f}")
            continue

        for (h, kg) in plan:
            if t.time >= TRUK_END:
                truk_done[idx] = True
                t.log("SELESAI_WAKTU", "Waktu habis saat eksekusi batch")
                break
            if h.trash_remaining < 0.01:
                continue
            t.move_to(h.x, h.y)
            if t.time >= TRUK_END:
                truk_done[idx] = True
                t.log("SELESAI_WAKTU", f"Waktu habis menuju Rumah-{h.id}")
                break
            actual = min(h.trash_remaining, CAP_TRUK - t.load)
            if actual > 0.01:
                t.collect_from_house(h, actual)
            if t.load >= CAP_TRUK * 0.95:
                break

# Kumpulkan semua log
all_logs = []
for g in gerobak_list:
    all_logs.extend(g.logs)
for t in truk_list:
    all_logs.extend(t.logs)

waktu_selesai_gerobak = max(min(g.time, GEROBAK_END) for g in gerobak_list)
waktu_selesai_truk    = max(min(t.time, TRUK_END)    for t in truk_list)
waktu_selesai_semua   = max(waktu_selesai_gerobak, waktu_selesai_truk)

print(f"Simulasi selesai ({iteration} iterasi)")
print(f"Total event tercatat: {len(all_logs)}")

rumah_selesai = sum(1 for h in houses if h.trash_remaining < 0.01)
rumah_belum   = NUM_HOUSES - rumah_selesai

print(f"\nSeluruh operasi selesai pada : {mins_to_hhmm(int(waktu_selesai_semua))}")
print(f"Sisa Rumah (belum terambil)  : {rumah_belum} rumah")
print(f"Sisa Rumah (terambil)        : {rumah_selesai}/{NUM_HOUSES} completed")
# Out:
# Menjalankan simulasi concurrent dengan sistem penjatahan...
# Simulasi selesai (70 iterasi)
# Total event tercatat: 141
#
# Seluruh operasi selesai pada : 11:56
# Sisa Rumah (belum terambil)  : 0 rumah
# Sisa Rumah (terambil)        : 100/100 completed

# %% [markdown]
# ## Laporan Hasil Simulasi

# %%
# Tampilkan menit dalam format Xj Ym
def mins_to_display(m: float) -> str:
    m = int(m)
    return f"{m//60}j {m%60}m" if m >= 60 else f"{m}m"

def bar_chart(val, total, width=20) -> str:
    filled = int(val / total * width) if total > 0 else 0
    return '█' * filled + '░' * (width - filled)

# Tambahan: Bertemu gerobak (Ya/Tidak) + Transfer Gerobak (kg)
# ============================================================

# Laporan Truk
print(f"LAPORAN TRUK SAMPAH")
print()
total_dist_truk = 0
total_trash_truk_dumped = 0

for t in truk_list:
    # Hitung total sampah yang dibuang ke TPS dari log
    dumped = sum(
        float(l.detail.split("buang ")[1].split("kg")[0])
        for l in t.logs if "BUANG_TPS" in l.event
    ) if any("BUANG_TPS" in l.event for l in t.logs) else 0

    end_time = min(int(t.time), TRUK_END)
    op_time  = end_time - TRUK_START

    # Cek apakah truk ini pernah menerima transfer dari gerobak
    pernah_terima = t.received_from_gerobak_kg > 0
    bertemu_str   = "Ya" if pernah_terima else "Tidak"
    transfer_str  = f"{t.received_from_gerobak_kg:.2f} kg" if pernah_terima else "- kg"

    print(f"\n{t.name()}")
    print(f"Jarak tempuh: {t.total_dist:.2f} satuan jarak")
    print(f"Waktu perjalanan: {t.total_time_travel:.1f} menit")
    print(f"Waktu loading: {t.total_time_load:.1f} menit")
    print(f"Total waktu operasi: {op_time:.0f} menit "
          f"({mins_to_hhmm(TRUK_START)} – {mins_to_hhmm(end_time)})")
    print(f"Trip ke TPS: {t.trips_to_tps}")
    print(f"Sampah dibuang ke TPS: {dumped:.2f} kg")
    print(f"Sisa di truk: {t.load:.2f} kg")
    print(f"Bertemu gerobak: {bertemu_str}")        # ← BARU
    print(f"Transfer dari gerobak: {transfer_str}") # ← BARU
    total_dist_truk += t.total_dist
    total_trash_truk_dumped += dumped

print(f"\nTotal jarak semua truk: {total_dist_truk:.2f} satuan jarak")
print(f"Total sampah ke TPS: {total_trash_truk_dumped:.2f} kg")
total_dist_gerobak = 0
total_trash_gerobak = 0

for g in gerobak_list:
    dumped = sum(
        float(l.detail.split("buang ")[1].split("kg")[0])
        for l in g.logs if "BUANG_TPS" in l.event
    ) if any("BUANG_TPS" in l.event for l in g.logs) else 0

    transferred = sum(
        float(l.detail.split("Transfer ")[1].split("kg")[0])
        for l in g.logs if "TITIP_TRUK" in l.event
    ) if any("TITIP_TRUK" in l.event for l in g.logs) else 0

    end_time = min(int(g.time), GEROBAK_END)
    op_time  = end_time - GEROBAK_START

    print(f"\n{g.name()}")
    print(f"Jarak tempuh: {g.total_dist:.2f} satuan jarak")
    print(f"Waktu perjalanan: {g.total_time_travel:.1f} menit")
    print(f"Waktu loading: {g.total_time_load:.1f} menit")
    print(f"Total waktu operasi: {op_time:.0f} menit " f"({mins_to_hhmm(GEROBAK_START)} – {mins_to_hhmm(end_time)})")
    print(f"Trip ke TPS: {g.trips_to_tps}")
    print(f"Trip ke Truk: {g.trips_to_truk}")
    print(f"Sampah ke TPS: {dumped:.2f} kg")
    print(f"Sampah titip ke Truk: {transferred:.2f} kg")
    print(f"Sisa di gerobak: {g.load:.2f} kg")
    total_dist_gerobak += g.total_dist
    total_trash_gerobak += dumped + transferred

print(f"\nTotal jarak semua gerobak: {total_dist_gerobak:.2f} satuan jarak")
print(f"Total sampah terangkut: {total_trash_gerobak:.2f} kg")

# Status TPS
print(f"STATUS TPS")
print()
total_tps = 0
for tps in tps_list:
    pct = tps.stored / tps.capacity * 100 if tps.capacity > 0 else 0
    bar = bar_chart(tps.stored, tps.capacity)
    print(f"\nTPS-{tps.id} ({tps.x:.0f},{tps.y:.0f})")
    print(f"Kapasitas: {tps.capacity:.1f} kg")
    print(f"Tersimpan: {tps.stored:.2f} kg [{bar}] {pct:.1f}%")
    print(f"Sisa ruang: {tps.available:.2f} kg")
    total_tps += tps.stored

# Sisa Sampah Rumah
print(f"SISA SAMPAH RUMAH TANGGA")
print()
remaining_houses = [h for h in houses if h.trash_remaining > 0.01]
total_remaining = sum(h.trash_remaining for h in houses)
print(f"Rumah masih ada sampah: {len(remaining_houses)} dari {NUM_HOUSES}")
print(f"Total sisa: {total_remaining:.2f} kg")
if remaining_houses:
    top5 = sorted(remaining_houses, key=lambda x: -x.trash_remaining)[:5]
    print(f"Top 5 rumah dengan sisa terbanyak:")
    for h in top5:
        print(f"Rumah-{h.id:3d}: {h.trash_remaining:.2f} kg " f"(dari {h.trash_initial:.2f} kg) di ({h.x:.1f},{h.y:.1f})")

# Ringkasan
print(f"RINGKASAN AKHIR")
print()
sisa_gerobak = sum(g.load for g in gerobak_list)
sisa_truk = sum(t.load for t in truk_list)
total_init = sum(h.trash_initial for h in houses)

print(f"Total sampah awal: {total_init:.2f} kg")
print(f"Di TPS (sudah dibuang): {total_tps:.2f} kg")
print(f"Masih di gerobak: {sisa_gerobak:.2f} kg (waktu habis)")
print(f"Masih di truk: {sisa_truk:.2f} kg (waktu habis)")
print(f"Sisa di rumah tangga: {total_remaining:.2f} kg")
accounted = total_tps + sisa_gerobak + sisa_truk + total_remaining
print(f"Total terakuntansi: {accounted:.2f} kg")
eff = total_tps / total_init * 100 if total_init > 0 else 0
print(f"\nEfisiensi ke TPS: {eff:.1f}%")
collected_pct = (total_tps + sisa_gerobak + sisa_truk) / total_init * 100 if total_init > 0 else 0
print(f"Sampah berhasil diangkut: {collected_pct:.1f}%")
selisih = abs(accounted - total_init)
assert selisih <= 0.01, (
    f"Neraca sampah tidak seimbang! "
    f"total_init={total_init:.2f}, terakuntansi={accounted:.2f}, "
    f"selisih={selisih:.4f} kg"
)
# Out:
# LAPORAN TRUK SAMPAH
#
#
# Truk-1
# Jarak tempuh: 144.40 satuan jarak
# Waktu perjalanan: 86.6 menit
# Waktu loading: 26.9 menit
# Total waktu operasi: 113 menit (08:00 – 09:53)
# Trip ke TPS: 1
# Sampah dibuang ke TPS: 67.32 kg
# Sisa di truk: 0.00 kg
# Bertemu gerobak: Tidak
# Transfer dari gerobak: - kg
#
# Truk-2
# Jarak tempuh: 125.23 satuan jarak
# Waktu perjalanan: 75.1 menit
# Waktu loading: 33.1 menit
# Total waktu operasi: 108 menit (08:00 – 09:48)
# Trip ke TPS: 1
# Sampah dibuang ke TPS: 82.77 kg
# Sisa di truk: 0.00 kg
# Bertemu gerobak: Tidak
# Transfer dari gerobak: - kg
#
# Truk-3
# Jarak tempuh: 139.09 satuan jarak
# Waktu perjalanan: 83.5 menit
# Waktu loading: 21.3 menit
# Total waktu operasi: 104 menit (08:00 – 09:44)
# Trip ke TPS: 1
# Sampah dibuang ke TPS: 53.25 kg
# Sisa di truk: 0.00 kg
# Bertemu gerobak: Tidak
# Transfer dari gerobak: - kg
#
# Total jarak semua truk: 408.72 satuan jarak
# Total sampah ke TPS: 203.34 kg
#
# Gerobak-1
# Jarak tempuh: 91.53 satuan jarak
# Waktu perjalanan: 274.6 menit
# Waktu loading: 82.1 menit
# Total waktu operasi: 356 menit (06:00 – 11:56)
# Trip ke TPS: 2
# Trip ke Truk: 0
# Sampah ke TPS: 20.52 kg
# Sampah titip ke Truk: 0.00 kg
# Sisa di gerobak: 0.00 kg
#
# Gerobak-2
# Jarak tempuh: 48.43 satuan jarak
# Waktu perjalanan: 145.3 menit
# Waktu loading: 60.0 menit
# Total waktu operasi: 205 menit (06:00 – 09:25)
# Trip ke TPS: 1
# Trip ke Truk: 0
# Sampah ke TPS: 15.00 kg
# Sampah titip ke Truk: 0.00 kg
# Sisa di gerobak: 0.00 kg
#
# Gerobak-3
# Jarak tempuh: 53.18 satuan jarak
# Waktu perjalanan: 159.6 menit
# Waktu loading: 97.0 menit
# Total waktu operasi: 256 menit (06:00 – 10:16)
# Trip ke TPS: 2
# Trip ke Truk: 0
# Sampah ke TPS: 24.26 kg
# Sampah titip ke Truk: 0.00 kg
# Sisa di gerobak: 0.00 kg
#
# Gerobak-4
# Jarak tempuh: 48.71 satuan jarak
# Waktu perjalanan: 146.1 menit
# Waktu loading: 113.4 menit
# Total waktu operasi: 259 menit (06:00 – 10:19)
# Trip ke TPS: 2
# Trip ke Truk: 0
# Sampah ke TPS: 28.36 kg
# Sampah titip ke Truk: 0.00 kg
# Sisa di gerobak: 0.00 kg
#
# Gerobak-5
# Jarak tempuh: 31.93 satuan jarak
# Waktu perjalanan: 95.8 menit
# Waktu loading: 113.4 menit
# Total waktu operasi: 209 menit (06:00 – 09:29)
# Trip ke TPS: 2
# Trip ke Truk: 0
# Sampah ke TPS: 28.34 kg
# Sampah titip ke Truk: 0.00 kg
# Sisa di gerobak: 0.00 kg
#
# Gerobak-6
# Jarak tempuh: 45.24 satuan jarak
# Waktu perjalanan: 135.7 menit
# Waktu loading: 60.0 menit
# Total waktu operasi: 195 menit (06:00 – 09:15)
# Trip ke TPS: 1
# Trip ke Truk: 0
# Sampah ke TPS: 15.00 kg
# Sampah titip ke Truk: 0.00 kg
# Sisa di gerobak: 0.00 kg
#
# Gerobak-7
# Jarak tempuh: 76.53 satuan jarak
# Waktu perjalanan: 229.6 menit
# Waktu loading: 71.0 menit
# Total waktu operasi: 300 menit (06:00 – 11:00)
# Trip ke TPS: 2
# Trip ke Truk: 0
# Sampah ke TPS: 17.74 kg
# Sampah titip ke Truk: 0.00 kg
# Sisa di gerobak: 0.00 kg
#
# Total jarak semua gerobak: 395.57 satuan jarak
# Total sampah terangkut: 149.22 kg
# STATUS TPS
#
#
# TPS-1 (8,5)
# Kapasitas: 443.0 kg
# Tersimpan: 114.33 kg [█████░░░░░░░░░░░░░░░] 25.8%
# Sisa ruang: 328.67 kg
#
# TPS-2 (44,43)
# Kapasitas: 415.1 kg
# Tersimpan: 208.38 kg [██████████░░░░░░░░░░] 50.2%
# Sisa ruang: 206.72 kg
#
# TPS-3 (49,12)
# Kapasitas: 473.5 kg
# Tersimpan: 29.85 kg [█░░░░░░░░░░░░░░░░░░░] 6.3%
# Sisa ruang: 443.65 kg
# SISA SAMPAH RUMAH TANGGA
#
# Rumah masih ada sampah: 0 dari 100
# Total sisa: 0.00 kg
# RINGKASAN AKHIR
#
# Total sampah awal: 352.56 kg
# Di TPS (sudah dibuang): 352.56 kg
# Masih di gerobak: 0.00 kg (waktu habis)
# Masih di truk: 0.00 kg (waktu habis)
# Sisa di rumah tangga: 0.00 kg
# Total terakuntansi: 352.56 kg
#
# Efisiensi ke TPS: 100.0%
# Sampah berhasil diangkut: 100.0%

# %% [markdown]
# ## Report Pergerakan Sampah

# %%
def time_val(log: LogEntry) -> int:
    h, m = log.time.split(':')
    return int(h)*60 + int(m)

sorted_logs = sorted(all_logs, key=time_val)

print(f"REPORT PERGERAKAN SAMPAH (KRONOLOGI)")
print()
print(f"Total event: {len(sorted_logs)}")
print()

# Print per aktor
for actor_name in ([f"Gerobak-{g.id}" for g in gerobak_list] + [f"Truk-{t.id}" for t in truk_list]):
    actor_logs = [l for l in all_logs if l.actor == actor_name]
    if not actor_logs:
        continue
    print(f"[{actor_name}] – {len(actor_logs)} events")
    print(f"{'─'*62}")
    for log in actor_logs:
        print(f"{log.time}  {log.event:<22} {log.detail[:48]}")
    print()

# Kronologi gabungan (semua event)
print(f"KRONOLOGI GABUNGAN")
print()
print(f"{'Waktu':<7} {'Aktor':<12} {'Event':<22} {'Detail':<30}")
print(f"{'─'*67}")
for log in sorted_logs:
    print(f"{log.time:<7} {log.actor:<12} {log.event:<22} {log.detail[:30]}")

# ── Kumpulkan semua event TITIP_TRUK dari semua gerobak ──
transfer_events = [
    l for l in all_logs
    if l.event == "TITIP_TRUK"
]

print()
print(f"{'═'*67}")
print(f"RINGKASAN TRANSFER GEROBAK → TRUK")
print(f"{'═'*67}")
print()

if transfer_events:
    # Header tabel
    print(f"{'Jam':<8} {'Dari':<12} {'Ke':<12} {'Transfer':<12} Detail")
    print(f"{'─'*67}")

    total_transfer_kg = 0.0
    for l in sorted(transfer_events, key=time_val):
        try:
            kg_str  = l.detail.split("Transfer ")[1].split("kg")[0]
            truk_id = l.detail.split(" ke ")[1].split(" |")[0]
            kg_val  = float(kg_str)
            total_transfer_kg += kg_val
        except (IndexError, ValueError):
            kg_str  = "?"
            truk_id = "?"
            kg_val  = 0.0

        print(f"{l.time:<8} {l.actor:<12} {truk_id:<12} {kg_val:<10.2f}kg  {l.detail[:28]}")

    print(f"{'─'*67}")
    print(f"Total kejadian transfer : {len(transfer_events)} kali")
    print(f"Total sampah ditransfer : {total_transfer_kg:.2f} kg")

else:
    print("Tidak ada transfer gerobak → truk yang terjadi.")
    print("(Pastikan simulasi menggunakan loop concurrent)")
# Out:
# REPORT PERGERAKAN SAMPAH (KRONOLOGI)
#
# Total event: 141
#
# [Gerobak-1] – 11 events
# ──────────────────────────────────────────────────────────────
# 06:00  MULAI                  Posisi awal (29.4,23.3) | zona TPS-3
# 06:11  AMBIL_SAMPAH           Rumah-83 (31.4,20.8) ambil 0.77kg | sisa rumah 0
# 06:36  AMBIL_SAMPAH           Rumah-17 (37.2,16.6) ambil 1.80kg | sisa rumah 0
# 06:59  AMBIL_SAMPAH           Rumah-75 (39.4,10.4) ambil 1.93kg | sisa rumah 0
# 07:18  AMBIL_SAMPAH           Rumah-2 (39.6,7.5) ambil 5.21kg | sisa rumah 0.0
# 07:36  AMBIL_SAMPAH           Rumah-23 (45.1,7.1) ambil 0.33kg | sisa rumah 0.
# 07:50  AMBIL_SAMPAH           Rumah-63 (46.6,7.6) ambil 4.81kg | sisa rumah 0.
# 08:35  BUANG_TPS              TPS-3 (49.3,12.0) buang 14.85kg | TPS 29.9/473.5
# 10:25  AMBIL_SAMPAH           Rumah-66 (21.3,29.4) ambil 5.67kg | sisa rumah 0
# 11:56  BUANG_TPS              TPS-2 (44.0,43.0) buang 5.67kg | TPS 208.4/415.1
# 11:56  SELESAI_SAMPAH         Zona TPS-3 bersih | jarak 91.53 | waktu 357 meni
#
# [Gerobak-2] – 7 events
# ──────────────────────────────────────────────────────────────
# 06:00  MULAI                  Posisi awal (18.4,35.1) | zona TPS-3
# 06:05  AMBIL_SAMPAH           Rumah-65 (17.2,35.2) ambil 1.03kg | sisa rumah 0
# 06:27  AMBIL_SAMPAH           Rumah-56 (13.5,36.7) ambil 4.86kg | sisa rumah 0
# 06:51  AMBIL_SAMPAH           Rumah-81 (9.0,38.0) ambil 4.93kg | sisa rumah 0.
# 07:08  AMBIL_SAMPAH           Rumah-49 (6.9,40.2) ambil 4.18kg | sisa rumah 1.
# 09:25  BUANG_TPS              TPS-1 (7.8,4.7) buang 15.00kg | TPS 30.0/443.0kg
# 09:25  SELESAI_SAMPAH         Zona TPS-3 bersih | jarak 48.43 | waktu 205 meni
#
# [Gerobak-3] – 9 events
# ──────────────────────────────────────────────────────────────
# 06:00  MULAI                  Posisi awal (43.5,43.8) | zona TPS-2
# 06:16  AMBIL_SAMPAH           Rumah-20 (44.4,44.8) ambil 6.48kg | sisa rumah 0
# 06:40  AMBIL_SAMPAH           Rumah-85 (41.3,47.8) ambil 5.32kg | sisa rumah 0
# 07:10  AMBIL_SAMPAH           Rumah-34 (48.8,45.2) ambil 3.20kg | sisa rumah 2
# 07:56  BUANG_TPS              TPS-2 (44.0,43.0) buang 15.00kg | TPS 30.0/415.1
# 08:17  AMBIL_SAMPAH           Rumah-34 (48.8,45.2) ambil 2.49kg | sisa rumah 0
# 09:18  AMBIL_SAMPAH           Rumah-68 (44.4,29.9) ambil 6.77kg | sisa rumah 0
# 10:16  BUANG_TPS              TPS-2 (44.0,43.0) buang 9.26kg | TPS 52.6/415.1k
# 10:16  SELESAI_SAMPAH         Zona TPS-2 bersih | jarak 53.18 | waktu 257 meni
#
# [Gerobak-4] – 11 events
# ──────────────────────────────────────────────────────────────
# 06:00  MULAI                  Posisi awal (39.5,32.2) | zona TPS-2
# 06:11  AMBIL_SAMPAH           Rumah-62 (41.5,33.2) ambil 2.59kg | sisa rumah 0
# 06:25  AMBIL_SAMPAH           Rumah-98 (42.0,34.7) ambil 4.28kg | sisa rumah 0
# 06:47  AMBIL_SAMPAH           Rumah-25 (44.6,37.4) ambil 5.58kg | sisa rumah 0
# 07:04  AMBIL_SAMPAH           Rumah-37 (47.6,39.9) ambil 2.55kg | sisa rumah 2
# 07:48  BUANG_TPS              TPS-2 (44.0,43.0) buang 15.00kg | TPS 15.0/415.1
# 08:07  AMBIL_SAMPAH           Rumah-37 (47.6,39.9) ambil 2.47kg | sisa rumah 0
# 08:39  AMBIL_SAMPAH           Rumah-72 (45.3,32.7) ambil 4.72kg | sisa rumah 0
# 09:07  AMBIL_SAMPAH           Rumah-50 (45.5,27.8) ambil 6.17kg | sisa rumah 0
# 10:19  BUANG_TPS              TPS-2 (44.0,43.0) buang 13.36kg | TPS 43.4/415.1
# 10:19  SELESAI_SAMPAH         Zona TPS-2 bersih | jarak 48.71 | waktu 260 meni
#
# [Gerobak-5] – 12 events
# ──────────────────────────────────────────────────────────────
# 06:00  MULAI                  Posisi awal (11.6,18.8) | zona TPS-1
# 06:09  AMBIL_SAMPAH           Rumah-28 (12.8,18.4) ambil 2.85kg | sisa rumah 0
# 06:27  AMBIL_SAMPAH           Rumah-27 (11.5,20.3) ambil 5.37kg | sisa rumah 0
# 06:45  AMBIL_SAMPAH           Rumah-77 (10.9,15.0) ambil 1.21kg | sisa rumah 0
# 06:59  AMBIL_SAMPAH           Rumah-58 (11.2,12.2) ambil 2.67kg | sisa rumah 0
# 07:07  AMBIL_SAMPAH           Rumah-82 (11.8,11.5) ambil 2.90kg | sisa rumah 0
# 08:01  BUANG_TPS              TPS-1 (7.8,4.7) buang 15.00kg | TPS 15.0/443.0kg
# 08:24  AMBIL_SAMPAH           Rumah-3 (10.7,3.0) ambil 6.45kg | sisa rumah 0.0
# 08:36  AMBIL_SAMPAH           Rumah-80 (10.2,1.5) ambil 3.47kg | sisa rumah 0.
# 08:47  AMBIL_SAMPAH           Rumah-10 (9.6,0.1) ambil 3.42kg | sisa rumah 0.0
# 09:29  BUANG_TPS              TPS-1 (7.8,4.7) buang 13.34kg | TPS 58.3/443.0kg
# 09:29  SELESAI_SAMPAH         Zona TPS-1 bersih | jarak 31.93 | waktu 209 meni
#
# [Gerobak-6] – 10 events
# ──────────────────────────────────────────────────────────────
# 06:00  MULAI                  Posisi awal (24.1,23.4) | zona TPS-1
# 06:15  AMBIL_SAMPAH           Rumah-40 (19.8,21.4) ambil 0.88kg | sisa rumah 0
# 06:34  AMBIL_SAMPAH           Rumah-41 (16.1,22.7) ambil 3.34kg | sisa rumah 0
# 07:13  AMBIL_SAMPAH           Rumah-16 (6.5,27.3) ambil 3.52kg | sisa rumah 0.
# 07:20  AMBIL_SAMPAH           Rumah-96 (4.2,27.0) ambil 0.29kg | sisa rumah 0.
# 07:57  AMBIL_SAMPAH           Rumah-30 (3.8,16.1) ambil 1.94kg | sisa rumah 0.
# 08:07  AMBIL_SAMPAH           Rumah-46 (4.8,15.3) ambil 3.28kg | sisa rumah 0.
# 08:13  AMBIL_SAMPAH           Rumah-6 (4.3,14.9) ambil 1.75kg | sisa rumah 1.8
# 09:15  BUANG_TPS              TPS-1 (7.8,4.7) buang 15.00kg | TPS 45.0/443.0kg
# 09:15  SELESAI_SAMPAH         Zona TPS-1 bersih | jarak 45.24 | waktu 196 meni
#
# [Gerobak-7] – 8 events
# ──────────────────────────────────────────────────────────────
# 06:00  MULAI                  Posisi awal (26.8,23.3) | zona TPS-1
# 06:35  AMBIL_SAMPAH           Rumah-84 (24.1,15.8) ambil 5.78kg | sisa rumah 0
# 06:57  AMBIL_SAMPAH           Rumah-18 (28.1,15.1) ambil 5.08kg | sisa rumah 0
# 07:07  AMBIL_SAMPAH           Rumah-22 (28.6,15.3) ambil 4.14kg | sisa rumah 1
# 08:40  BUANG_TPS              TPS-3 (49.3,12.0) buang 15.00kg | TPS 15.0/473.5
# 10:16  AMBIL_SAMPAH           Rumah-92 (19.3,10.7) ambil 2.74kg | sisa rumah 0
# 11:00  BUANG_TPS              TPS-1 (7.8,4.7) buang 2.74kg | TPS 114.3/443.0kg
# 11:00  SELESAI_SAMPAH         Zona TPS-1 bersih | jarak 76.53 | waktu 301 meni
#
# [Truk-1] – 25 events
# ──────────────────────────────────────────────────────────────
# 08:00  MULAI                  Mulai dari TPS-1 (7.8,4.7)
# 08:01  AMBIL_SAMPAH           Rumah-31 (7.7,6.4) ambil 4.19kg | sisa rumah 0.0
# 08:03  AMBIL_SAMPAH           Rumah-24 (7.2,6.9) ambil 5.13kg | sisa rumah 0.0
# 08:04  AMBIL_SAMPAH           Rumah-29 (6.1,8.3) ambil 0.40kg | sisa rumah 0.0
# 08:06  AMBIL_SAMPAH           Rumah-53 (7.8,9.0) ambil 4.93kg | sisa rumah 0.0
# 08:09  AMBIL_SAMPAH           Rumah-32 (4.4,6.5) ambil 2.29kg | sisa rumah 0.0
# 08:11  AMBIL_SAMPAH           Rumah-12 (4.5,4.9) ambil 4.27kg | sisa rumah 0.0
# 08:13  AMBIL_SAMPAH           Rumah-48 (2.4,4.0) ambil 5.01kg | sisa rumah 0.0
# 08:18  AMBIL_SAMPAH           Rumah-35 (1.9,11.1) ambil 1.19kg | sisa rumah 0.
# 08:21  AMBIL_SAMPAH           Rumah-6 (4.3,14.9) ambil 1.85kg | sisa rumah 0.0
# 08:26  AMBIL_SAMPAH           Rumah-82 (11.8,11.5) ambil 0.16kg | sisa rumah 0
# 08:30  AMBIL_SAMPAH           Rumah-44 (14.0,5.7) ambil 2.38kg | sisa rumah 0.
# 08:33  AMBIL_SAMPAH           Rumah-36 (14.7,3.1) ambil 5.26kg | sisa rumah 0.
# 08:35  AMBIL_SAMPAH           Rumah-39 (18.0,4.2) ambil 0.22kg | sisa rumah 0.
# 08:38  AMBIL_SAMPAH           Rumah-55 (21.2,2.2) ambil 5.93kg | sisa rumah 0.
# 08:42  AMBIL_SAMPAH           Rumah-42 (25.2,2.4) ambil 4.44kg | sisa rumah 0.
# 08:45  AMBIL_SAMPAH           Rumah-95 (30.9,1.2) ambil 1.52kg | sisa rumah 0.
# 08:51  AMBIL_SAMPAH           Rumah-87 (29.9,9.0) ambil 6.20kg | sisa rumah 0.
# 08:55  AMBIL_SAMPAH           Rumah-22 (28.6,15.3) ambil 1.53kg | sisa rumah 0
# 09:08  AMBIL_SAMPAH           Rumah-70 (15.5,30.6) ambil 0.92kg | sisa rumah 0
# 09:15  AMBIL_SAMPAH           Rumah-91 (19.2,40.2) ambil 5.61kg | sisa rumah 0
# 09:20  AMBIL_SAMPAH           Rumah-67 (19.7,47.2) ambil 2.58kg | sisa rumah 0
# 09:22  AMBIL_SAMPAH           Rumah-90 (15.7,47.6) ambil 1.31kg | sisa rumah 0
# 09:53  BUANG_TPS              TPS-2 (44.0,43.0) buang 67.32kg | TPS 119.9/415.
# 09:53  SELESAI_SAMPAH         Semua sampah habis | jarak 144.40
#
# [Truk-2] – 27 events
# ──────────────────────────────────────────────────────────────
# 08:00  MULAI                  Mulai dari TPS-2 (44.0,43.0)
# 08:04  AMBIL_SAMPAH           Rumah-76 (37.6,40.2) ambil 0.76kg | sisa rumah 0
# 08:05  AMBIL_SAMPAH           Rumah-15 (37.2,40.7) ambil 6.24kg | sisa rumah 0
# 08:07  AMBIL_SAMPAH           Rumah-61 (34.9,40.7) ambil 0.95kg | sisa rumah 0
# 08:09  AMBIL_SAMPAH           Rumah-4 (33.2,43.0) ambil 0.93kg | sisa rumah 0.
# 08:10  AMBIL_SAMPAH           Rumah-38 (32.5,43.9) ambil 1.86kg | sisa rumah 0
# 08:11  AMBIL_SAMPAH           Rumah-64 (33.9,44.5) ambil 0.42kg | sisa rumah 0
# 08:14  AMBIL_SAMPAH           Rumah-100 (30.5,43.1) ambil 3.28kg | sisa rumah
# 08:17  AMBIL_SAMPAH           Rumah-69 (27.2,43.1) ambil 4.29kg | sisa rumah 0
# 08:20  AMBIL_SAMPAH           Rumah-86 (25.5,40.1) ambil 5.09kg | sisa rumah 0
# 08:24  AMBIL_SAMPAH           Rumah-33 (30.6,39.6) ambil 6.96kg | sisa rumah 0
# 08:26  AMBIL_SAMPAH           Rumah-71 (31.4,38.1) ambil 3.74kg | sisa rumah 0
# 08:28  AMBIL_SAMPAH           Rumah-1 (32.4,36.4) ambil 2.45kg | sisa rumah 0.
# 08:33  AMBIL_SAMPAH           Rumah-47 (27.9,31.7) ambil 4.65kg | sisa rumah 0
# 08:37  AMBIL_SAMPAH           Rumah-74 (31.9,28.7) ambil 5.20kg | sisa rumah 0
# 08:38  AMBIL_SAMPAH           Rumah-59 (33.7,27.4) ambil 1.24kg | sisa rumah 0
# 08:41  AMBIL_SAMPAH           Rumah-57 (35.7,25.2) ambil 5.47kg | sisa rumah 0
# 08:43  AMBIL_SAMPAH           Rumah-93 (37.3,23.9) ambil 5.98kg | sisa rumah 0
# 08:46  AMBIL_SAMPAH           Rumah-21 (39.2,22.3) ambil 6.21kg | sisa rumah 0
# 08:49  AMBIL_SAMPAH           Rumah-5 (39.7,26.5) ambil 0.87kg | sisa rumah 0.
# 08:51  AMBIL_SAMPAH           Rumah-79 (42.8,26.3) ambil 0.31kg | sisa rumah 0
# 08:55  AMBIL_SAMPAH           Rumah-88 (47.9,23.9) ambil 3.85kg | sisa rumah 0
# 09:03  AMBIL_SAMPAH           Rumah-14 (36.5,29.6) ambil 1.92kg | sisa rumah 0
# 09:08  AMBIL_SAMPAH           Rumah-11 (32.4,24.4) ambil 4.62kg | sisa rumah 0
# 09:23  AMBIL_SAMPAH           Rumah-9 (31.9,48.2) ambil 5.48kg | sisa rumah 0.
# 09:48  BUANG_TPS              TPS-2 (44.0,43.0) buang 82.77kg | TPS 202.7/415.
# 09:48  SELESAI_SAMPAH         Semua sampah habis | jarak 125.23
#
# [Truk-3] – 21 events
# ──────────────────────────────────────────────────────────────
# 08:00  MULAI                  Mulai dari TPS-3 (49.3,12.0)
# 08:02  AMBIL_SAMPAH           Rumah-60 (49.3,14.1) ambil 3.82kg | sisa rumah 0
# 08:05  AMBIL_SAMPAH           Rumah-45 (50.0,10.0) ambil 3.74kg | sisa rumah 0
# 08:12  AMBIL_SAMPAH           Rumah-8 (48.5,20.3) ambil 6.94kg | sisa rumah 0.
# 08:28  AMBIL_SAMPAH           Rumah-73 (23.3,23.7) ambil 1.48kg | sisa rumah 0
# 08:31  AMBIL_SAMPAH           Rumah-52 (20.0,25.6) ambil 5.27kg | sisa rumah 0
# 08:33  AMBIL_SAMPAH           Rumah-26 (18.4,27.6) ambil 1.43kg | sisa rumah 0
# 08:34  AMBIL_SAMPAH           Rumah-43 (18.8,28.2) ambil 4.69kg | sisa rumah 0
# 08:36  AMBIL_SAMPAH           Rumah-89 (17.3,27.3) ambil 0.68kg | sisa rumah 0
# 08:38  AMBIL_SAMPAH           Rumah-19 (14.8,27.2) ambil 3.34kg | sisa rumah 0
# 08:41  AMBIL_SAMPAH           Rumah-51 (12.0,28.3) ambil 4.87kg | sisa rumah 0
# 08:43  AMBIL_SAMPAH           Rumah-78 (8.6,30.1) ambil 0.85kg | sisa rumah 0.
# 08:47  AMBIL_SAMPAH           Rumah-54 (7.4,33.5) ambil 6.56kg | sisa rumah 0.
# 08:49  AMBIL_SAMPAH           Rumah-13 (4.4,35.9) ambil 0.26kg | sisa rumah 0.
# 08:52  AMBIL_SAMPAH           Rumah-7 (3.6,31.8) ambil 1.38kg | sisa rumah 0.0
# 08:58  AMBIL_SAMPAH           Rumah-94 (3.7,40.3) ambil 6.11kg | sisa rumah 0.
# 08:59  AMBIL_SAMPAH           Rumah-97 (2.9,41.9) ambil 0.06kg | sisa rumah 0.
# 09:02  AMBIL_SAMPAH           Rumah-49 (6.9,40.2) ambil 1.16kg | sisa rumah 0.
# 09:08  AMBIL_SAMPAH           Rumah-99 (0.0,46.9) ambil 0.61kg | sisa rumah 0.
# 09:44  BUANG_TPS              TPS-1 (7.8,4.7) buang 53.25kg | TPS 111.6/443.0k
# 09:44  SELESAI_SAMPAH         Semua sampah habis | jarak 139.09
#
# KRONOLOGI GABUNGAN
#
# Waktu   Aktor        Event                  Detail
# ───────────────────────────────────────────────────────────────────
# 06:00   Gerobak-1    MULAI                  Posisi awal (29.4,23.3) | zona
# 06:00   Gerobak-2    MULAI                  Posisi awal (18.4,35.1) | zona
# 06:00   Gerobak-3    MULAI                  Posisi awal (43.5,43.8) | zona
# 06:00   Gerobak-4    MULAI                  Posisi awal (39.5,32.2) | zona
# 06:00   Gerobak-5    MULAI                  Posisi awal (11.6,18.8) | zona
# 06:00   Gerobak-6    MULAI                  Posisi awal (24.1,23.4) | zona
# 06:00   Gerobak-7    MULAI                  Posisi awal (26.8,23.3) | zona
# 06:05   Gerobak-2    AMBIL_SAMPAH           Rumah-65 (17.2,35.2) ambil 1.0
# 06:09   Gerobak-5    AMBIL_SAMPAH           Rumah-28 (12.8,18.4) ambil 2.8
# 06:11   Gerobak-1    AMBIL_SAMPAH           Rumah-83 (31.4,20.8) ambil 0.7
# 06:11   Gerobak-4    AMBIL_SAMPAH           Rumah-62 (41.5,33.2) ambil 2.5
# 06:15   Gerobak-6    AMBIL_SAMPAH           Rumah-40 (19.8,21.4) ambil 0.8
# 06:16   Gerobak-3    AMBIL_SAMPAH           Rumah-20 (44.4,44.8) ambil 6.4
# 06:25   Gerobak-4    AMBIL_SAMPAH           Rumah-98 (42.0,34.7) ambil 4.2
# 06:27   Gerobak-2    AMBIL_SAMPAH           Rumah-56 (13.5,36.7) ambil 4.8
# 06:27   Gerobak-5    AMBIL_SAMPAH           Rumah-27 (11.5,20.3) ambil 5.3
# 06:34   Gerobak-6    AMBIL_SAMPAH           Rumah-41 (16.1,22.7) ambil 3.3
# 06:35   Gerobak-7    AMBIL_SAMPAH           Rumah-84 (24.1,15.8) ambil 5.7
# 06:36   Gerobak-1    AMBIL_SAMPAH           Rumah-17 (37.2,16.6) ambil 1.8
# 06:40   Gerobak-3    AMBIL_SAMPAH           Rumah-85 (41.3,47.8) ambil 5.3
# 06:45   Gerobak-5    AMBIL_SAMPAH           Rumah-77 (10.9,15.0) ambil 1.2
# 06:47   Gerobak-4    AMBIL_SAMPAH           Rumah-25 (44.6,37.4) ambil 5.5
# 06:51   Gerobak-2    AMBIL_SAMPAH           Rumah-81 (9.0,38.0) ambil 4.93
# 06:57   Gerobak-7    AMBIL_SAMPAH           Rumah-18 (28.1,15.1) ambil 5.0
# 06:59   Gerobak-1    AMBIL_SAMPAH           Rumah-75 (39.4,10.4) ambil 1.9
# 06:59   Gerobak-5    AMBIL_SAMPAH           Rumah-58 (11.2,12.2) ambil 2.6
# 07:04   Gerobak-4    AMBIL_SAMPAH           Rumah-37 (47.6,39.9) ambil 2.5
# 07:07   Gerobak-5    AMBIL_SAMPAH           Rumah-82 (11.8,11.5) ambil 2.9
# 07:07   Gerobak-7    AMBIL_SAMPAH           Rumah-22 (28.6,15.3) ambil 4.1
# 07:08   Gerobak-2    AMBIL_SAMPAH           Rumah-49 (6.9,40.2) ambil 4.18
# 07:10   Gerobak-3    AMBIL_SAMPAH           Rumah-34 (48.8,45.2) ambil 3.2
# 07:13   Gerobak-6    AMBIL_SAMPAH           Rumah-16 (6.5,27.3) ambil 3.52
# 07:18   Gerobak-1    AMBIL_SAMPAH           Rumah-2 (39.6,7.5) ambil 5.21k
# 07:20   Gerobak-6    AMBIL_SAMPAH           Rumah-96 (4.2,27.0) ambil 0.29
# 07:36   Gerobak-1    AMBIL_SAMPAH           Rumah-23 (45.1,7.1) ambil 0.33
# 07:48   Gerobak-4    BUANG_TPS              TPS-2 (44.0,43.0) buang 15.00k
# 07:50   Gerobak-1    AMBIL_SAMPAH           Rumah-63 (46.6,7.6) ambil 4.81
# 07:56   Gerobak-3    BUANG_TPS              TPS-2 (44.0,43.0) buang 15.00k
# 07:57   Gerobak-6    AMBIL_SAMPAH           Rumah-30 (3.8,16.1) ambil 1.94
# 08:00   Truk-1       MULAI                  Mulai dari TPS-1 (7.8,4.7)
# 08:00   Truk-2       MULAI                  Mulai dari TPS-2 (44.0,43.0)
# 08:00   Truk-3       MULAI                  Mulai dari TPS-3 (49.3,12.0)
# 08:01   Gerobak-5    BUANG_TPS              TPS-1 (7.8,4.7) buang 15.00kg
# 08:01   Truk-1       AMBIL_SAMPAH           Rumah-31 (7.7,6.4) ambil 4.19k
# 08:02   Truk-3       AMBIL_SAMPAH           Rumah-60 (49.3,14.1) ambil 3.8
# 08:03   Truk-1       AMBIL_SAMPAH           Rumah-24 (7.2,6.9) ambil 5.13k
# 08:04   Truk-1       AMBIL_SAMPAH           Rumah-29 (6.1,8.3) ambil 0.40k
# 08:04   Truk-2       AMBIL_SAMPAH           Rumah-76 (37.6,40.2) ambil 0.7
# 08:05   Truk-2       AMBIL_SAMPAH           Rumah-15 (37.2,40.7) ambil 6.2
# 08:05   Truk-3       AMBIL_SAMPAH           Rumah-45 (50.0,10.0) ambil 3.7
# 08:06   Truk-1       AMBIL_SAMPAH           Rumah-53 (7.8,9.0) ambil 4.93k
# 08:07   Gerobak-4    AMBIL_SAMPAH           Rumah-37 (47.6,39.9) ambil 2.4
# 08:07   Gerobak-6    AMBIL_SAMPAH           Rumah-46 (4.8,15.3) ambil 3.28
# 08:07   Truk-2       AMBIL_SAMPAH           Rumah-61 (34.9,40.7) ambil 0.9
# 08:09   Truk-1       AMBIL_SAMPAH           Rumah-32 (4.4,6.5) ambil 2.29k
# 08:09   Truk-2       AMBIL_SAMPAH           Rumah-4 (33.2,43.0) ambil 0.93
# 08:10   Truk-2       AMBIL_SAMPAH           Rumah-38 (32.5,43.9) ambil 1.8
# 08:11   Truk-1       AMBIL_SAMPAH           Rumah-12 (4.5,4.9) ambil 4.27k
# 08:11   Truk-2       AMBIL_SAMPAH           Rumah-64 (33.9,44.5) ambil 0.4
# 08:12   Truk-3       AMBIL_SAMPAH           Rumah-8 (48.5,20.3) ambil 6.94
# 08:13   Gerobak-6    AMBIL_SAMPAH           Rumah-6 (4.3,14.9) ambil 1.75k
# 08:13   Truk-1       AMBIL_SAMPAH           Rumah-48 (2.4,4.0) ambil 5.01k
# 08:14   Truk-2       AMBIL_SAMPAH           Rumah-100 (30.5,43.1) ambil 3.
# 08:17   Gerobak-3    AMBIL_SAMPAH           Rumah-34 (48.8,45.2) ambil 2.4
# 08:17   Truk-2       AMBIL_SAMPAH           Rumah-69 (27.2,43.1) ambil 4.2
# 08:18   Truk-1       AMBIL_SAMPAH           Rumah-35 (1.9,11.1) ambil 1.19
# 08:20   Truk-2       AMBIL_SAMPAH           Rumah-86 (25.5,40.1) ambil 5.0
# 08:21   Truk-1       AMBIL_SAMPAH           Rumah-6 (4.3,14.9) ambil 1.85k
# 08:24   Gerobak-5    AMBIL_SAMPAH           Rumah-3 (10.7,3.0) ambil 6.45k
# 08:24   Truk-2       AMBIL_SAMPAH           Rumah-33 (30.6,39.6) ambil 6.9
# 08:26   Truk-1       AMBIL_SAMPAH           Rumah-82 (11.8,11.5) ambil 0.1
# 08:26   Truk-2       AMBIL_SAMPAH           Rumah-71 (31.4,38.1) ambil 3.7
# 08:28   Truk-2       AMBIL_SAMPAH           Rumah-1 (32.4,36.4) ambil 2.45
# 08:28   Truk-3       AMBIL_SAMPAH           Rumah-73 (23.3,23.7) ambil 1.4
# 08:30   Truk-1       AMBIL_SAMPAH           Rumah-44 (14.0,5.7) ambil 2.38
# 08:31   Truk-3       AMBIL_SAMPAH           Rumah-52 (20.0,25.6) ambil 5.2
# 08:33   Truk-1       AMBIL_SAMPAH           Rumah-36 (14.7,3.1) ambil 5.26
# 08:33   Truk-2       AMBIL_SAMPAH           Rumah-47 (27.9,31.7) ambil 4.6
# 08:33   Truk-3       AMBIL_SAMPAH           Rumah-26 (18.4,27.6) ambil 1.4
# 08:34   Truk-3       AMBIL_SAMPAH           Rumah-43 (18.8,28.2) ambil 4.6
# 08:35   Gerobak-1    BUANG_TPS              TPS-3 (49.3,12.0) buang 14.85k
# 08:35   Truk-1       AMBIL_SAMPAH           Rumah-39 (18.0,4.2) ambil 0.22
# 08:36   Gerobak-5    AMBIL_SAMPAH           Rumah-80 (10.2,1.5) ambil 3.47
# 08:36   Truk-3       AMBIL_SAMPAH           Rumah-89 (17.3,27.3) ambil 0.6
# 08:37   Truk-2       AMBIL_SAMPAH           Rumah-74 (31.9,28.7) ambil 5.2
# 08:38   Truk-1       AMBIL_SAMPAH           Rumah-55 (21.2,2.2) ambil 5.93
# 08:38   Truk-2       AMBIL_SAMPAH           Rumah-59 (33.7,27.4) ambil 1.2
# 08:38   Truk-3       AMBIL_SAMPAH           Rumah-19 (14.8,27.2) ambil 3.3
# 08:39   Gerobak-4    AMBIL_SAMPAH           Rumah-72 (45.3,32.7) ambil 4.7
# 08:40   Gerobak-7    BUANG_TPS              TPS-3 (49.3,12.0) buang 15.00k
# 08:41   Truk-2       AMBIL_SAMPAH           Rumah-57 (35.7,25.2) ambil 5.4
# 08:41   Truk-3       AMBIL_SAMPAH           Rumah-51 (12.0,28.3) ambil 4.8
# 08:42   Truk-1       AMBIL_SAMPAH           Rumah-42 (25.2,2.4) ambil 4.44
# 08:43   Truk-2       AMBIL_SAMPAH           Rumah-93 (37.3,23.9) ambil 5.9
# 08:43   Truk-3       AMBIL_SAMPAH           Rumah-78 (8.6,30.1) ambil 0.85
# 08:45   Truk-1       AMBIL_SAMPAH           Rumah-95 (30.9,1.2) ambil 1.52
# 08:46   Truk-2       AMBIL_SAMPAH           Rumah-21 (39.2,22.3) ambil 6.2
# 08:47   Gerobak-5    AMBIL_SAMPAH           Rumah-10 (9.6,0.1) ambil 3.42k
# 08:47   Truk-3       AMBIL_SAMPAH           Rumah-54 (7.4,33.5) ambil 6.56
# 08:49   Truk-2       AMBIL_SAMPAH           Rumah-5 (39.7,26.5) ambil 0.87
# 08:49   Truk-3       AMBIL_SAMPAH           Rumah-13 (4.4,35.9) ambil 0.26
# 08:51   Truk-1       AMBIL_SAMPAH           Rumah-87 (29.9,9.0) ambil 6.20
# 08:51   Truk-2       AMBIL_SAMPAH           Rumah-79 (42.8,26.3) ambil 0.3
# 08:52   Truk-3       AMBIL_SAMPAH           Rumah-7 (3.6,31.8) ambil 1.38k
# 08:55   Truk-1       AMBIL_SAMPAH           Rumah-22 (28.6,15.3) ambil 1.5
# 08:55   Truk-2       AMBIL_SAMPAH           Rumah-88 (47.9,23.9) ambil 3.8
# 08:58   Truk-3       AMBIL_SAMPAH           Rumah-94 (3.7,40.3) ambil 6.11
# 08:59   Truk-3       AMBIL_SAMPAH           Rumah-97 (2.9,41.9) ambil 0.06
# 09:02   Truk-3       AMBIL_SAMPAH           Rumah-49 (6.9,40.2) ambil 1.16
# 09:03   Truk-2       AMBIL_SAMPAH           Rumah-14 (36.5,29.6) ambil 1.9
# 09:07   Gerobak-4    AMBIL_SAMPAH           Rumah-50 (45.5,27.8) ambil 6.1
# 09:08   Truk-1       AMBIL_SAMPAH           Rumah-70 (15.5,30.6) ambil 0.9
# 09:08   Truk-2       AMBIL_SAMPAH           Rumah-11 (32.4,24.4) ambil 4.6
# 09:08   Truk-3       AMBIL_SAMPAH           Rumah-99 (0.0,46.9) ambil 0.61
# 09:15   Gerobak-6    BUANG_TPS              TPS-1 (7.8,4.7) buang 15.00kg
# 09:15   Gerobak-6    SELESAI_SAMPAH         Zona TPS-1 bersih | jarak 45.2
# 09:15   Truk-1       AMBIL_SAMPAH           Rumah-91 (19.2,40.2) ambil 5.6
# 09:18   Gerobak-3    AMBIL_SAMPAH           Rumah-68 (44.4,29.9) ambil 6.7
# 09:20   Truk-1       AMBIL_SAMPAH           Rumah-67 (19.7,47.2) ambil 2.5
# 09:22   Truk-1       AMBIL_SAMPAH           Rumah-90 (15.7,47.6) ambil 1.3
# 09:23   Truk-2       AMBIL_SAMPAH           Rumah-9 (31.9,48.2) ambil 5.48
# 09:25   Gerobak-2    BUANG_TPS              TPS-1 (7.8,4.7) buang 15.00kg
# 09:25   Gerobak-2    SELESAI_SAMPAH         Zona TPS-3 bersih | jarak 48.4
# 09:29   Gerobak-5    BUANG_TPS              TPS-1 (7.8,4.7) buang 13.34kg
# 09:29   Gerobak-5    SELESAI_SAMPAH         Zona TPS-1 bersih | jarak 31.9
# 09:44   Truk-3       BUANG_TPS              TPS-1 (7.8,4.7) buang 53.25kg
# 09:44   Truk-3       SELESAI_SAMPAH         Semua sampah habis | jarak 139
# 09:48   Truk-2       BUANG_TPS              TPS-2 (44.0,43.0) buang 82.77k
# 09:48   Truk-2       SELESAI_SAMPAH         Semua sampah habis | jarak 125
# 09:53   Truk-1       BUANG_TPS              TPS-2 (44.0,43.0) buang 67.32k
# 09:53   Truk-1       SELESAI_SAMPAH         Semua sampah habis | jarak 144
# 10:16   Gerobak-3    BUANG_TPS              TPS-2 (44.0,43.0) buang 9.26kg
# 10:16   Gerobak-3    SELESAI_SAMPAH         Zona TPS-2 bersih | jarak 53.1
# 10:16   Gerobak-7    AMBIL_SAMPAH           Rumah-92 (19.3,10.7) ambil 2.7
# 10:19   Gerobak-4    BUANG_TPS              TPS-2 (44.0,43.0) buang 13.36k
# 10:19   Gerobak-4    SELESAI_SAMPAH         Zona TPS-2 bersih | jarak 48.7
# 10:25   Gerobak-1    AMBIL_SAMPAH           Rumah-66 (21.3,29.4) ambil 5.6
# 11:00   Gerobak-7    BUANG_TPS              TPS-1 (7.8,4.7) buang 2.74kg |
# 11:00   Gerobak-7    SELESAI_SAMPAH         Zona TPS-1 bersih | jarak 76.5
# 11:56   Gerobak-1    BUANG_TPS              TPS-2 (44.0,43.0) buang 5.67kg
# 11:56   Gerobak-1    SELESAI_SAMPAH         Zona TPS-3 bersih | jarak 91.5
#
# ═══════════════════════════════════════════════════════════════════
# RINGKASAN TRANSFER GEROBAK → TRUK
# ═══════════════════════════════════════════════════════════════════
#
# Tidak ada transfer gerobak → truk yang terjadi.
# (Pastikan simulasi menggunakan loop concurrent)

# %% [markdown]
# ## Visualisasi Hasil

# %%
# Cek konsistensi koordinat
vis_errors = []
for hid, (sx, sy) in _snapshot_houses.items():
    h = next(h for h in houses if h.id == hid)
    if abs(h.x - sx) > 1e-9 or abs(h.y - sy) > 1e-9:
        vis_errors.append(f"Rumah-{hid}: snapshot({sx},{sy}) != plot({h.x},{h.y})")
for tid, (sx, sy) in _snapshot_tps.items():
    t = next(t for t in tps_list if t.id == tid)
    if abs(t.x - sx) > 1e-9 or abs(t.y - sy) > 1e-9:
        vis_errors.append(f"TPS-{tid}: snapshot({sx},{sy}) != plot({t.x},{t.y})")
if vis_errors:
    print("Koordinat tidak konsisten")
    for e in vis_errors: print(f"{e}")
else:
    print("Koordinat konsisten")

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

fig, axes = plt.subplots(2, 2, figsize=(16, 14))
fig.suptitle('Hasil Simulasi Pengangkutan Sampah', fontsize=16, fontweight='bold', y=0.98)

# Plot 1: Peta Akhir
ax = axes[0, 0]
ax.set_facecolor('#f5f5f5')
# Rumah: warna berdasarkan sisa sampah
for h in houses:
    color = 'green' if h.trash_remaining < 0.1 else ('orange' if h.trash_remaining < 3 else 'red')
    ax.scatter(h.x, h.y, c=color, s=30, alpha=0.7, zorder=2)
# TPS
tps_colors = ['#1a6b3c', '#155a8a', '#8b1a1a']
for i, tps in enumerate(tps_list):
    ax.scatter(tps.x, tps.y, c=tps_colors[i], s=200, marker='s', zorder=5, edgecolors='black')
    ax.annotate(f'TPS-{tps.id}', (tps.x, tps.y), xytext=(3,3), textcoords='offset points', fontsize=8, fontweight='bold')
# Posisi akhir gerobak & truk
for g in gerobak_list:
    ax.scatter(g.x, g.y, c='blue', s=100, marker='^', zorder=6, alpha=0.8)
for t in truk_list:
    ax.scatter(t.x, t.y, c='purple', s=150, marker='D', zorder=6, alpha=0.8)
legend_handles = [
    mpatches.Patch(color='green', label='Rumah (bersih)'),
    mpatches.Patch(color='orange', label='Rumah (sisa < 3kg)'),
    mpatches.Patch(color='red', label='Rumah (sisa ≥ 3kg)'),
    mpatches.Patch(color='blue', label='Gerobak (posisi akhir)'),
    mpatches.Patch(color='purple', label='Truk (posisi akhir)'),
]
ax.legend(handles=legend_handles, fontsize=7, loc='upper right')
ax.set_title('Peta Akhir Desa')
ax.set_xlim(-1, GRID_SIZE+1); ax.set_ylim(-1, GRID_SIZE+1)
ax.grid(True, alpha=0.3)

# Plot 2: Jarak Tempuh
ax = axes[0, 1]
names_g = [g.name() for g in gerobak_list]
dists_g = [g.total_dist for g in gerobak_list]
names_t = [t.name() for t in truk_list]
dists_t = [t.total_dist for t in truk_list]
x_g = np.arange(len(names_g))
x_t = np.arange(len(names_t)) + len(names_g) + 1
bars_g = ax.bar(x_g, dists_g, color='#4CAF50', alpha=0.85, label='Gerobak')
bars_t = ax.bar(x_t, dists_t, color='#2196F3', alpha=0.85, label='Truk')
ax.bar_label(bars_g, fmt='%.1f', fontsize=8)
ax.bar_label(bars_t, fmt='%.1f', fontsize=8)
ax.set_xticks(list(x_g) + list(x_t))
ax.set_xticklabels(names_g + names_t, rotation=30, fontsize=8)
ax.set_title('Jarak Tempuh per Agen')
ax.set_ylabel('Satuan Jarak')
ax.legend(fontsize=9)
ax.grid(True, alpha=0.3, axis='y')

# Plot 3: Status TPS
ax = axes[1, 0]
tps_names = [f'TPS-{t.id}' for t in tps_list]
stored    = [t.stored for t in tps_list]
available = [t.available for t in tps_list]
x = np.arange(len(tps_names))
b1 = ax.bar(x, stored, label='Tersimpan', color='#FF7043', alpha=0.85)
b2 = ax.bar(x, available, bottom=stored, label='Sisa kapasitas', color='#B0BEC5', alpha=0.6)
ax.bar_label(b1, fmt='%.0f kg', label_type='center', fontsize=9)
ax.set_xticks(x); ax.set_xticklabels(tps_names, fontsize=10)
ax.set_title('Kapasitas TPS')
ax.set_ylabel('kg')
ax.legend(fontsize=9)
ax.grid(True, alpha=0.3, axis='y')

# Plot 4: Breakdown Waktu
ax = axes[1, 1]
all_agents = gerobak_list + truk_list
agent_names = [a.name() for a in all_agents]
travel_times = [a.total_time_travel for a in all_agents]
load_times = [a.total_time_load for a in all_agents]
idle_times = [max(0,
    (min(int(a.time), GEROBAK_END if 'Gerobak' in a.name() else TRUK_END) -
        (GEROBAK_START if 'Gerobak' in a.name() else TRUK_START)) -
    a.total_time_travel - a.total_time_load
) for a in all_agents]
x = np.arange(len(agent_names))
b1 = ax.bar(x, travel_times, label='Perjalanan', color='#42A5F5', alpha=0.85)
b2 = ax.bar(x, load_times, bottom=travel_times, label='Loading', color='#FF7043', alpha=0.85)
b3 = ax.bar(x, idle_times, bottom=[travel_times[i]+load_times[i] for i in range(len(all_agents))], label='Idle/Tunggu', color='#B0BEC5', alpha=0.6)
ax.set_xticks(x); ax.set_xticklabels(agent_names, rotation=40, fontsize=8)
ax.set_title('Breakdown Waktu per Agen')
ax.set_ylabel('Menit')
ax.legend(fontsize=9)
ax.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.savefig('hasil_simulasi.png', dpi=120, bbox_inches='tight')
plt.show()
print("Grafik saved")
# Out:
# Koordinat konsisten
# Grafik saved
